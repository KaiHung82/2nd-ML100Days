# %% [markdown]
# ## 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#     1. 我選擇  [Two Sigma: Using News to Predict Stock Movements](https://www.kaggle.com/c/two-sigma-financial-news) 當作資料集
#     2. 因為我想要從中知道如何投資股票標的
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     1. 主辦單位是 Two Sigma
#     2. Market data provided by Intrinio.
#     3. News data provided by Thomson Reuters.
# 3. 蒐集而來的資料型態為何
#     1. 都是公司提供的結構化資料
#     2. 但是主要想探討的是 新聞 文字，每一個長度不依
# 4. 這組資料想解決的問題如何評估
#     1. 這組資料主要想解決的問題是如何用新聞資料去預測股價走勢
#     2. 測量誤差的方法，可以使用 MSE，因為我覺得算是回歸問題
#
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     1. 如何提高每台計程車一天的載客次數
#     2. 如何讓車隊出現在需要用車的尖峰時刻
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     1. 從自己公司的資料庫，裡面有車隊的載客紀錄包含了(上車地點、上車時間)
#     2. 參考天氣預報，隨著降雨機決定派車的數量(利用爬網技術，抓取中央氣象局的資料)
# 3. 蒐集而來的資料型態為何
#     1. 都算是結構化資料
#     1. 上車地點會用坐標軸的方式呈現(X軸 Y軸)，資料型態為 int
#     2. 上車時間也是用 int
#     3. 天氣預報中的每天的降雨機率，資料型態分別為(date、int)
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     1. 模型的 X 有 座標軸、上車時間、降雨機率
#     2. 模型的 Y 應該是派車數量
#     3. 準確率應該是看 MSE，因為我覺得算是一個回歸問題，所以我用 MSE 處理

# %% [markdown]
# # 作業三
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    n = len(y);
    Subtraction = y - y_hat;
    MSE = sum(Subtraction**2)/n
    return MSE

# %%
def mean_absolute_error(y, y_hat):
    n = len(y)
    Subtraction = y - y_hat;
    MAE = sum(np.absolute(Subtraction))/n
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 206.137
# The Mean absolute error is 11.262
